# %%
import pickle
from sklearn.tree import export_text
import pandas as pd
import numpy as np

# %%
filename = 'model.pkl'
with open(filename, 'rb') as file:
    clf = pickle.load(file)

# %%
print(clf.get_depth())
print(clf.get_n_leaves())
# Out:
# 30
# 18253

# %%
for name, value in zip(clf.features, clf.feature_importances_):
  print(f'{name}: {value}')
# Out:
# Debt Consolidation Loan: 0.007820864512607559
# Changed_Credit_Limit: 0.07541078234808375
# Annual_Income: 0.07014154376595008
# Num_of_Loan: 0.022213565731604785
# Credit_History_Age: 0.20521106958206323
# Num_of_Delayed_Payment: 0.05939904587009031
# Num_Bank_Accounts: 0.029854014570083683
# Delay_from_due_date: 0.06795467907001519
# Num_Credit_Inquiries: 0.03913662963232784
# Num_Credit_Card: 0.03380598949826663
# Outstanding_Debt: 0.18442786335654007
# Interest_Rate: 0.0629668363167222
# Credit_Mix: 0.14165711574564469

# %%
df = pd.read_csv("./test.csv")
X = df[clf.features]
X = np.array(X)

# %%
def get_decision_path(clf, X_test):
    n_nodes = clf.tree_.node_count
    children_left = clf.tree_.children_left
    children_right = clf.tree_.children_right
    feature = clf.tree_.feature
    threshold = clf.tree_.threshold
    node_indicator = clf.decision_path(X_test)
    leaf_id = clf.apply(X_test)
    classes = clf.predict(X_test)

    for sample_id in range(0, len(X_test)):
        node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]
        ]

        print("Rules used to predict sample {id}:\n".format(id=sample_id))
        for node_id in node_index:
            # continue to the next node if it is a leaf node
            if leaf_id[sample_id] == node_id:
                continue

            # check if value of the split feature for sample 0 is below threshold
            if X_test[sample_id, feature[node_id]] <= threshold[node_id]:
                threshold_sign = "<="
            else:
                threshold_sign = ">"

            print(
                "decision node {node} : (X_test[{sample}, {feature}] = {value}) "
                "{inequality} {threshold})".format(
                    node=node_id,
                    sample=sample_id,
                    feature=clf.features[feature[node_id]],
                    value=X_test[sample_id, feature[node_id]],
                    inequality=threshold_sign,
                    threshold=threshold[node_id],
                )
            )
        print(f'Sample {sample_id} is {clf.labels[classes[sample_id]]}')
        print("*"*50)
        print()

# %%
get_decision_path(clf, X)
# Out:
# Rules used to predict sample 0:
#
# decision node 0 : (X_test[0, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[0, Outstanding_Debt] = 758.44) <= 1255.469970703125)
# decision node 2 : (X_test[0, Annual_Income] = 25546.26) <= 93708.23828125)
# decision node 3 : (X_test[0, Num_Credit_Inquiries] = 5.0) > 4.5)
# decision node 2703 : (X_test[0, Interest_Rate] = 14.0) <= 21.0)
# decision node 2704 : (X_test[0, Changed_Credit_Limit] = 7.83) <= 8.21500015258789)
# decision node 2705 : (X_test[0, Credit_Mix] = 1.0) > 0.5)
# decision node 2711 : (X_test[0, Num_of_Loan] = 5.0) <= 5.5)
# decision node 2712 : (X_test[0, Annual_Income] = 25546.26) > 9870.66748046875)
# decision node 2740 : (X_test[0, Delay_from_due_date] = 16.0) > 5.5)
# decision node 2764 : (X_test[0, Num_Bank_Accounts] = 8.0) > 6.5)
# decision node 3236 : (X_test[0, Outstanding_Debt] = 758.44) <= 1009.5150146484375)
# decision node 3237 : (X_test[0, Changed_Credit_Limit] = 7.83) > 7.329999923706055)
# decision node 3371 : (X_test[0, Num_of_Delayed_Payment] = 10.0) <= 16.5)
# decision node 3372 : (X_test[0, Num_Credit_Inquiries] = 5.0) <= 8.5)
# Sample 0 is Standard
# **************************************************
#
# Rules used to predict sample 1:
#
# decision node 0 : (X_test[1, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[1, Outstanding_Debt] = 1373.82) > 1255.469970703125)
# decision node 7429 : (X_test[1, Interest_Rate] = 20.0) > 14.5)
# decision node 9031 : (X_test[1, Changed_Credit_Limit] = 23.08) > 14.835000038146973)
# decision node 16459 : (X_test[1, Outstanding_Debt] = 1373.82) <= 2646.3050537109375)
# decision node 16460 : (X_test[1, Interest_Rate] = 20.0) <= 20.5)
# decision node 16461 : (X_test[1, Outstanding_Debt] = 1373.82) <= 1484.7699584960938)
# decision node 16462 : (X_test[1, Num_Credit_Inquiries] = 6.0) <= 8.5)
# decision node 16463 : (X_test[1, Credit_History_Age] = 250.0) > 206.5)
# decision node 16583 : (X_test[1, Annual_Income] = 33999.48) > 7714.40234375)
# decision node 16585 : (X_test[1, Annual_Income] = 33999.48) <= 103020.49609375)
# decision node 16586 : (X_test[1, Num_of_Delayed_Payment] = 13.0) <= 17.5)
# decision node 16587 : (X_test[1, Num_Credit_Card] = 3.0) <= 4.5)
# Sample 1 is Standard
# **************************************************
#
# Rules used to predict sample 2:
#
# decision node 0 : (X_test[2, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[2, Outstanding_Debt] = 589.67) <= 1255.469970703125)
# decision node 2 : (X_test[2, Annual_Income] = 17321.505) <= 93708.23828125)
# decision node 3 : (X_test[2, Num_Credit_Inquiries] = 2.0) <= 4.5)
# decision node 4 : (X_test[2, Annual_Income] = 17321.505) <= 33371.955078125)
# decision node 5 : (X_test[2, Credit_History_Age] = 367.0) > 293.5)
# decision node 779 : (X_test[2, Outstanding_Debt] = 589.67) > 298.5399932861328)
# decision node 953 : (X_test[2, Num_Credit_Card] = 7.0) > 4.5)
# decision node 1211 : (X_test[2, Annual_Income] = 17321.505) > 12002.357421875)
# decision node 1251 : (X_test[2, Annual_Income] = 17321.505) <= 32450.9501953125)
# decision node 1252 : (X_test[2, Interest_Rate] = 13.0) <= 15.5)
# decision node 1253 : (X_test[2, Outstanding_Debt] = 589.67) > 571.9849853515625)
# decision node 1367 : (X_test[2, Delay_from_due_date] = 19.0) > 11.5)
# decision node 1377 : (X_test[2, Credit_History_Age] = 367.0) <= 402.5)
# decision node 1378 : (X_test[2, Annual_Income] = 17321.505) <= 24442.4150390625)
# decision node 1379 : (X_test[2, Changed_Credit_Limit] = 7.64) <= 7.9700000286102295)
# decision node 1380 : (X_test[2, Interest_Rate] = 13.0) <= 14.5)
# Sample 2 is Standard
# **************************************************
#
# Rules used to predict sample 3:
#
# decision node 0 : (X_test[3, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[3, Outstanding_Debt] = 203.04) <= 1255.469970703125)
# decision node 2 : (X_test[3, Annual_Income] = 34144.14) <= 93708.23828125)
# decision node 3 : (X_test[3, Num_Credit_Inquiries] = 7.0) > 4.5)
# decision node 2703 : (X_test[3, Interest_Rate] = 15.0) <= 21.0)
# decision node 2704 : (X_test[3, Changed_Credit_Limit] = 18.5) > 8.21500015258789)
# decision node 3420 : (X_test[3, Num_Credit_Inquiries] = 7.0) <= 8.5)
# decision node 3421 : (X_test[3, Credit_History_Age] = 66.0) <= 188.5)
# decision node 3422 : (X_test[3, Interest_Rate] = 15.0) <= 18.5)
# decision node 3423 : (X_test[3, Delay_from_due_date] = 27.0) > 10.5)
# decision node 3565 : (X_test[3, Annual_Income] = 34144.14) > 10945.94775390625)
# decision node 3587 : (X_test[3, Outstanding_Debt] = 203.04) > 68.15999984741211)
# decision node 3607 : (X_test[3, Credit_History_Age] = 66.0) <= 165.5)
# decision node 3608 : (X_test[3, Num_of_Loan] = 7.0) > 2.5)
# decision node 3684 : (X_test[3, Num_of_Delayed_Payment] = 10.0) <= 17.5)
# decision node 3685 : (X_test[3, Credit_History_Age] = 66.0) <= 105.5)
# decision node 3686 : (X_test[3, Outstanding_Debt] = 203.04) <= 642.0500183105469)
# decision node 3687 : (X_test[3, Debt Consolidation Loan] = 0.0) <= 1.5)
# decision node 3688 : (X_test[3, Outstanding_Debt] = 203.04) <= 637.885009765625)
# decision node 3689 : (X_test[3, Num_Bank_Accounts] = 4.0) <= 7.5)
# Sample 3 is Standard
# **************************************************
#
# Rules used to predict sample 4:
#
# decision node 0 : (X_test[4, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[4, Outstanding_Debt] = 59.91) <= 1255.469970703125)
# decision node 2 : (X_test[4, Annual_Income] = 115661.32) > 93708.23828125)
# decision node 5696 : (X_test[4, Num_Credit_Inquiries] = 2.0) <= 8.5)
# decision node 5697 : (X_test[4, Annual_Income] = 115661.32) <= 125990.90234375)
# decision node 5698 : (X_test[4, Credit_History_Age] = 386.0) > 324.5)
# decision node 6502 : (X_test[4, Num_Credit_Inquiries] = 2.0) > 1.5)
# decision node 6588 : (X_test[4, Num_Bank_Accounts] = 8.0) > 4.5)
# decision node 6676 : (X_test[4, Annual_Income] = 115661.32) > 93947.2578125)
# decision node 6688 : (X_test[4, Credit_History_Age] = 386.0) > 329.5)
# decision node 6698 : (X_test[4, Annual_Income] = 115661.32) > 105116.0390625)
# decision node 6772 : (X_test[4, Num_of_Loan] = 2.0) > 1.5)
# decision node 6788 : (X_test[4, Changed_Credit_Limit] = 0.72) <= 3.225000023841858)
# decision node 6789 : (X_test[4, Changed_Credit_Limit] = 0.72) <= 2.9600000381469727)
# Sample 4 is Standard
# **************************************************
#
# Rules used to predict sample 5:
#
# decision node 0 : (X_test[5, Credit_Mix] = 0.0) <= 1.5)
# decision node 1 : (X_test[5, Outstanding_Debt] = 3467.82) > 1255.469970703125)
# decision node 7429 : (X_test[5, Interest_Rate] = 19.0) > 14.5)
# decision node 9031 : (X_test[5, Changed_Credit_Limit] = 20.87) > 14.835000038146973)
# decision node 16459 : (X_test[5, Outstanding_Debt] = 3467.82) > 2646.3050537109375)
# decision node 18863 : (X_test[5, Credit_Mix] = 0.0) <= 0.5)
# decision node 18864 : (X_test[5, Interest_Rate] = 19.0) <= 29.5)
# decision node 18865 : (X_test[5, Outstanding_Debt] = 3467.82) > 2658.6800537109375)
# decision node 18877 : (X_test[5, Debt Consolidation Loan] = 0.0) <= 1.5)
# decision node 18878 : (X_test[5, Num_Credit_Card] = 6.0) <= 9.5)
# decision node 18879 : (X_test[5, Interest_Rate] = 19.0) > 16.5)
# decision node 19069 : (X_test[5, Interest_Rate] = 19.0) > 18.5)
# decision node 19331 : (X_test[5, Delay_from_due_date] = 24.0) > 16.5)
# decision node 19427 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4830.619873046875)
# decision node 19428 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4628.10986328125)
# decision node 19429 : (X_test[5, Annual_Income] = 38721.44) <= 75964.80078125)
# decision node 19430 : (X_test[5, Outstanding_Debt] = 3467.82) > 2771.0550537109375)
# decision node 19528 : (X_test[5, Changed_Credit_Limit] = 20.87) <= 23.675000190734863)
# decision node 19529 : (X_test[5, Interest_Rate] = 19.0) <= 26.5)
# decision node 19530 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4538.599853515625)
# decision node 19531 : (X_test[5, Annual_Income] = 38721.44) > 19660.669921875)
# decision node 19641 : (X_test[5, Changed_Credit_Limit] = 20.87) > 20.565000534057617)
# decision node 19731 : (X_test[5, Changed_Credit_Limit] = 20.87) <= 21.984999656677246)
# decision node 19732 : (X_test[5, Interest_Rate] = 19.0) <= 19.5)
# decision node 19733 : (X_test[5, Credit_History_Age] = 165.0) > 160.0)
# Sample 5 is Standard
# **************************************************
#
# Rules used to predict sample 6:
#
# decision node 0 : (X_test[6, Credit_Mix] = 2.0) > 1.5)
# decision node 22206 : (X_test[6, Num_Credit_Card] = 7.0) > 2.5)
# decision node 24254 : (X_test[6, Delay_from_due_date] = 11.0) <= 15.5)
# decision node 24255 : (X_test[6, Num_Credit_Card] = 7.0) > 5.5)
# decision node 30697 : (X_test[6, Num_Bank_Accounts] = 3.0) <= 5.5)
# decision node 30698 : (X_test[6, Changed_Credit_Limit] = 4.77) > 2.6350001096725464)
# decision node 31298 : (X_test[6, Num_of_Delayed_Payment] = 5.0) <= 13.5)
# decision node 31299 : (X_test[6, Num_Credit_Card] = 7.0) > 6.5)
# decision node 32305 : (X_test[6, Outstanding_Debt] = 534.4) <= 863.3949890136719)
# decision node 32306 : (X_test[6, Debt Consolidation Loan] = 0.0) <= 0.5)
# decision node 32307 : (X_test[6, Outstanding_Debt] = 534.4) > 16.80500030517578)
# decision node 32317 : (X_test[6, Changed_Credit_Limit] = 4.77) <= 10.654999732971191)
# decision node 32318 : (X_test[6, Outstanding_Debt] = 534.4) > 52.209999084472656)
# decision node 32344 : (X_test[6, Credit_History_Age] = 266.0) <= 392.5)
# decision node 32345 : (X_test[6, Annual_Income] = 40646.19) > 18856.1318359375)
# decision node 32377 : (X_test[6, Annual_Income] = 40646.19) <= 41750.259765625)
# decision node 32378 : (X_test[6, Changed_Credit_Limit] = 4.77) <= 4.9049999713897705)
# decision node 32379 : (X_test[6, Outstanding_Debt] = 534.4) <= 733.52001953125)
# decision node 32380 : (X_test[6, Annual_Income] = 40646.19) > 20875.4482421875)
# decision node 32394 : (X_test[6, Credit_History_Age] = 266.0) > 258.5)
# decision node 32406 : (X_test[6, Num_Credit_Inquiries] = 4.0) > 0.5)
# decision node 32410 : (X_test[6, Interest_Rate] = 6.0) <= 10.0)
# Sample 6 is Standard
# **************************************************
#
# Rules used to predict sample 7:
#
# decision node 0 : (X_test[7, Credit_Mix] = 2.0) > 1.5)
# decision node 22206 : (X_test[7, Num_Credit_Card] = 6.0) > 2.5)
# decision node 24254 : (X_test[7, Delay_from_due_date] = 26.0) > 15.5)
# decision node 33718 : (X_test[7, Num_of_Delayed_Payment] = 8.0) <= 12.5)
# decision node 33719 : (X_test[7, Num_Bank_Accounts] = 5.0) <= 5.5)
# decision node 33720 : (X_test[7, Delay_from_due_date] = 26.0) > 20.5)
# decision node 34546 : (X_test[7, Num_Bank_Accounts] = 5.0) > 2.5)
# decision node 34964 : (X_test[7, Num_of_Delayed_Payment] = 8.0) > 5.5)
# decision node 35088 : (X_test[7, Annual_Income] = 34447.49) <= 65692.62890625)
# decision node 35089 : (X_test[7, Annual_Income] = 34447.49) <= 35517.599609375)
# decision node 35090 : (X_test[7, Interest_Rate] = 4.0) <= 10.5)
# decision node 35091 : (X_test[7, Credit_History_Age] = 366.0) > 359.5)
# decision node 35149 : (X_test[7, Changed_Credit_Limit] = 8.71) > 3.950000047683716)
# decision node 35157 : (X_test[7, Interest_Rate] = 4.0) <= 6.5)
# decision node 35158 : (X_test[7, Credit_History_Age] = 366.0) <= 384.5)
# decision node 35159 : (X_test[7, Interest_Rate] = 4.0) > 1.5)
# decision node 35161 : (X_test[7, Outstanding_Debt] = 922.3) > 523.1749877929688)
# decision node 35163 : (X_test[7, Changed_Credit_Limit] = 8.71) <= 11.994999885559082)
# Sample 7 is Good
# **************************************************
#
# Rules used to predict sample 8:
#
# decision node 0 : (X_test[8, Credit_Mix] = 2.0) > 1.5)
# decision node 22206 : (X_test[8, Num_Credit_Card] = 1.0) <= 2.5)
# decision node 22207 : (X_test[8, Annual_Income] = 90674.43) <= 118044.65625)
# decision node 22208 : (X_test[8, Annual_Income] = 90674.43) > 33388.37890625)
# decision node 22864 : (X_test[8, Outstanding_Debt] = 29.87) <= 1142.6650390625)
# decision node 22865 : (X_test[8, Credit_History_Age] = 209.0) > 205.5)
# decision node 22975 : (X_test[8, Credit_History_Age] = 209.0) <= 245.5)
# decision node 22976 : (X_test[8, Annual_Income] = 90674.43) > 37693.515625)
# decision node 22978 : (X_test[8, Outstanding_Debt] = 29.87) <= 484.6649932861328)
# decision node 22979 : (X_test[8, Credit_History_Age] = 209.0) <= 211.5)
# Sample 8 is Good
# **************************************************
#
# Rules used to predict sample 9:
#
# decision node 0 : (X_test[9, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[9, Outstanding_Debt] = 154.94) <= 1255.469970703125)
# decision node 2 : (X_test[9, Annual_Income] = 97515.78) > 93708.23828125)
# decision node 5696 : (X_test[9, Num_Credit_Inquiries] = 5.0) <= 8.5)
# decision node 5697 : (X_test[9, Annual_Income] = 97515.78) <= 125990.90234375)
# decision node 5698 : (X_test[9, Credit_History_Age] = 397.0) > 324.5)
# decision node 6502 : (X_test[9, Num_Credit_Inquiries] = 5.0) > 1.5)
# decision node 6588 : (X_test[9, Num_Bank_Accounts] = 5.0) > 4.5)
# decision node 6676 : (X_test[9, Annual_Income] = 97515.78) > 93947.2578125)
# decision node 6688 : (X_test[9, Credit_History_Age] = 397.0) > 329.5)
# decision node 6698 : (X_test[9, Annual_Income] = 97515.78) <= 105116.0390625)
# decision node 6699 : (X_test[9, Outstanding_Debt] = 154.94) <= 470.8450012207031)
# decision node 6700 : (X_test[9, Num_of_Loan] = 0.0) <= 1.5)
# decision node 6701 : (X_test[9, Delay_from_due_date] = 6.0) <= 20.5)
# decision node 6702 : (X_test[9, Num_of_Delayed_Payment] = 9.0) <= 10.0)
# decision node 6703 : (X_test[9, Credit_History_Age] = 397.0) > 349.5)
# decision node 6705 : (X_test[9, Credit_History_Age] = 397.0) > 394.5)
# Sample 9 is Standard
# **************************************************
