# %%
import pickle
from sklearn.tree import export_text
import pandas as pd
import numpy as np

# %%
filename = 'model.pkl'
with open(filename, 'rb') as file:
    clf = pickle.load(file)

# %%
print(clf.get_depth())
print(clf.get_n_leaves())
# Out:
# 25
# 15354

# %%
for name, value in zip(clf.features, clf.feature_importances_):
  print(f'{name}: {value}')
# Out:
# Debt Consolidation Loan: 0.008020890221777028
# Changed_Credit_Limit: 0.07566988194275512
# Annual_Income: 0.07077827670640056
# Num_of_Loan: 0.02200508112903976
# Credit_History_Age: 0.1903622597119117
# Num_of_Delayed_Payment: 0.05647770411217975
# Num_Bank_Accounts: 0.029641890113591755
# Delay_from_due_date: 0.06448792556369218
# Num_Credit_Inquiries: 0.03894724866337675
# Num_Credit_Card: 0.0346662193002076
# Outstanding_Debt: 0.19182735105682008
# Interest_Rate: 0.06548521292743335
# Credit_Mix: 0.1516300585508144

# %%
df = pd.read_csv("./test.csv")
X = df[clf.features]
X = np.array(X)

# %%
def get_decision_path(clf, X_test):
    n_nodes = clf.tree_.node_count
    children_left = clf.tree_.children_left
    children_right = clf.tree_.children_right
    feature = clf.tree_.feature
    threshold = clf.tree_.threshold
    node_indicator = clf.decision_path(X_test)
    leaf_id = clf.apply(X_test)
    classes = clf.predict(X_test)

    for sample_id in range(0, len(X_test)):
        node_index = node_indicator.indices[
            node_indicator.indptr[sample_id] : node_indicator.indptr[sample_id + 1]
        ]

        print("Rules used to predict sample {id}:\n".format(id=sample_id))
        for node_id in node_index:
            # continue to the next node if it is a leaf node
            if leaf_id[sample_id] == node_id:
                continue

            # check if value of the split feature for sample 0 is below threshold
            if X_test[sample_id, feature[node_id]] <= threshold[node_id]:
                threshold_sign = "<="
            else:
                threshold_sign = ">"

            print(
                "decision node {node} : (X_test[{sample}, {feature}] = {value}) "
                "{inequality} {threshold})".format(
                    node=node_id,
                    sample=sample_id,
                    feature=clf.features[feature[node_id]],
                    value=X_test[sample_id, feature[node_id]],
                    inequality=threshold_sign,
                    threshold=threshold[node_id],
                )
            )
        print(f'Sample {sample_id} is {clf.labels[classes[sample_id]]}')
        print("*"*50)
        print()

# %%
get_decision_path(clf, X)
# Out:
# Rules used to predict sample 0:
#
# decision node 0 : (X_test[0, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[0, Outstanding_Debt] = 758.44) <= 1255.469970703125)
# decision node 2 : (X_test[0, Annual_Income] = 25546.26) <= 93708.23828125)
# decision node 3 : (X_test[0, Num_Credit_Inquiries] = 5.0) > 4.5)
# decision node 2533 : (X_test[0, Credit_Mix] = 1.0) > 0.5)
# decision node 2549 : (X_test[0, Changed_Credit_Limit] = 7.83) <= 8.21500015258789)
# decision node 2550 : (X_test[0, Interest_Rate] = 14.0) <= 26.0)
# decision node 2551 : (X_test[0, Num_of_Loan] = 5.0) <= 5.5)
# decision node 2552 : (X_test[0, Annual_Income] = 25546.26) > 9870.66748046875)
# decision node 2580 : (X_test[0, Delay_from_due_date] = 16.0) > 5.5)
# decision node 2604 : (X_test[0, Num_Bank_Accounts] = 8.0) > 6.5)
# decision node 3032 : (X_test[0, Outstanding_Debt] = 758.44) <= 1009.5150146484375)
# decision node 3033 : (X_test[0, Changed_Credit_Limit] = 7.83) > 7.329999923706055)
# decision node 3163 : (X_test[0, Num_of_Delayed_Payment] = 10.0) <= 16.5)
# decision node 3164 : (X_test[0, Num_Credit_Inquiries] = 5.0) <= 8.5)
# Sample 0 is Standard
# **************************************************
#
# Rules used to predict sample 1:
#
# decision node 0 : (X_test[1, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[1, Outstanding_Debt] = 1373.82) > 1255.469970703125)
# decision node 6863 : (X_test[1, Interest_Rate] = 20.0) > 14.5)
# decision node 8421 : (X_test[1, Changed_Credit_Limit] = 23.08) > 14.835000038146973)
# decision node 13719 : (X_test[1, Outstanding_Debt] = 1373.82) <= 2646.3050537109375)
# decision node 13720 : (X_test[1, Interest_Rate] = 20.0) <= 20.5)
# decision node 13721 : (X_test[1, Outstanding_Debt] = 1373.82) <= 1484.7699584960938)
# decision node 13722 : (X_test[1, Num_Credit_Inquiries] = 6.0) <= 8.5)
# decision node 13723 : (X_test[1, Credit_History_Age] = 250.0) > 206.5)
# decision node 13843 : (X_test[1, Annual_Income] = 33999.48) > 7714.40234375)
# decision node 13845 : (X_test[1, Annual_Income] = 33999.48) <= 103020.49609375)
# decision node 13846 : (X_test[1, Num_of_Delayed_Payment] = 13.0) <= 17.5)
# decision node 13847 : (X_test[1, Num_Credit_Card] = 3.0) <= 4.5)
# Sample 1 is Standard
# **************************************************
#
# Rules used to predict sample 2:
#
# decision node 0 : (X_test[2, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[2, Outstanding_Debt] = 589.67) <= 1255.469970703125)
# decision node 2 : (X_test[2, Annual_Income] = 17321.505) <= 93708.23828125)
# decision node 3 : (X_test[2, Num_Credit_Inquiries] = 2.0) <= 4.5)
# decision node 4 : (X_test[2, Annual_Income] = 17321.505) <= 33371.955078125)
# decision node 5 : (X_test[2, Credit_History_Age] = 367.0) > 293.5)
# decision node 751 : (X_test[2, Outstanding_Debt] = 589.67) > 298.5399932861328)
# decision node 919 : (X_test[2, Num_Credit_Card] = 7.0) > 4.5)
# decision node 1179 : (X_test[2, Annual_Income] = 17321.505) > 12002.357421875)
# decision node 1215 : (X_test[2, Annual_Income] = 17321.505) <= 32450.9501953125)
# decision node 1216 : (X_test[2, Interest_Rate] = 13.0) <= 15.5)
# decision node 1217 : (X_test[2, Outstanding_Debt] = 589.67) > 571.9849853515625)
# decision node 1323 : (X_test[2, Delay_from_due_date] = 19.0) > 11.5)
# decision node 1333 : (X_test[2, Credit_History_Age] = 367.0) <= 402.5)
# decision node 1334 : (X_test[2, Annual_Income] = 17321.505) <= 24442.4150390625)
# decision node 1335 : (X_test[2, Changed_Credit_Limit] = 7.64) <= 7.9700000286102295)
# decision node 1336 : (X_test[2, Interest_Rate] = 13.0) <= 14.5)
# Sample 2 is Standard
# **************************************************
#
# Rules used to predict sample 3:
#
# decision node 0 : (X_test[3, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[3, Outstanding_Debt] = 203.04) <= 1255.469970703125)
# decision node 2 : (X_test[3, Annual_Income] = 34144.14) <= 93708.23828125)
# decision node 3 : (X_test[3, Num_Credit_Inquiries] = 7.0) > 4.5)
# decision node 2533 : (X_test[3, Credit_Mix] = 1.0) > 0.5)
# decision node 2549 : (X_test[3, Changed_Credit_Limit] = 18.5) > 8.21500015258789)
# decision node 3213 : (X_test[3, Num_Credit_Inquiries] = 7.0) <= 8.5)
# decision node 3214 : (X_test[3, Credit_History_Age] = 66.0) <= 188.5)
# decision node 3215 : (X_test[3, Interest_Rate] = 15.0) <= 18.5)
# decision node 3216 : (X_test[3, Delay_from_due_date] = 27.0) > 10.5)
# decision node 3358 : (X_test[3, Annual_Income] = 34144.14) > 10945.94775390625)
# decision node 3380 : (X_test[3, Outstanding_Debt] = 203.04) > 68.15999984741211)
# decision node 3398 : (X_test[3, Credit_History_Age] = 66.0) <= 165.5)
# decision node 3399 : (X_test[3, Num_of_Loan] = 7.0) > 2.5)
# decision node 3475 : (X_test[3, Num_of_Delayed_Payment] = 10.0) <= 17.5)
# decision node 3476 : (X_test[3, Credit_History_Age] = 66.0) <= 105.5)
# decision node 3477 : (X_test[3, Outstanding_Debt] = 203.04) <= 642.0500183105469)
# decision node 3478 : (X_test[3, Debt Consolidation Loan] = 0.0) <= 1.5)
# decision node 3479 : (X_test[3, Outstanding_Debt] = 203.04) <= 637.885009765625)
# decision node 3480 : (X_test[3, Num_Bank_Accounts] = 4.0) <= 7.5)
# Sample 3 is Standard
# **************************************************
#
# Rules used to predict sample 4:
#
# decision node 0 : (X_test[4, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[4, Outstanding_Debt] = 59.91) <= 1255.469970703125)
# decision node 2 : (X_test[4, Annual_Income] = 115661.32) > 93708.23828125)
# decision node 5154 : (X_test[4, Num_Credit_Inquiries] = 2.0) <= 8.5)
# decision node 5155 : (X_test[4, Annual_Income] = 115661.32) <= 125990.90234375)
# decision node 5156 : (X_test[4, Credit_History_Age] = 386.0) > 324.5)
# decision node 5950 : (X_test[4, Num_Credit_Inquiries] = 2.0) > 1.5)
# decision node 6036 : (X_test[4, Num_Bank_Accounts] = 8.0) > 4.5)
# decision node 6120 : (X_test[4, Annual_Income] = 115661.32) > 93947.2578125)
# decision node 6132 : (X_test[4, Credit_History_Age] = 386.0) > 329.5)
# decision node 6142 : (X_test[4, Annual_Income] = 115661.32) > 105116.0390625)
# decision node 6216 : (X_test[4, Num_of_Loan] = 2.0) > 1.5)
# decision node 6232 : (X_test[4, Changed_Credit_Limit] = 0.72) <= 3.225000023841858)
# decision node 6233 : (X_test[4, Changed_Credit_Limit] = 0.72) <= 2.9600000381469727)
# Sample 4 is Standard
# **************************************************
#
# Rules used to predict sample 5:
#
# decision node 0 : (X_test[5, Credit_Mix] = 0.0) <= 1.5)
# decision node 1 : (X_test[5, Outstanding_Debt] = 3467.82) > 1255.469970703125)
# decision node 6863 : (X_test[5, Interest_Rate] = 19.0) > 14.5)
# decision node 8421 : (X_test[5, Changed_Credit_Limit] = 20.87) > 14.835000038146973)
# decision node 13719 : (X_test[5, Outstanding_Debt] = 3467.82) > 2646.3050537109375)
# decision node 15651 : (X_test[5, Credit_Mix] = 0.0) <= 0.5)
# decision node 15652 : (X_test[5, Interest_Rate] = 19.0) <= 29.5)
# decision node 15653 : (X_test[5, Outstanding_Debt] = 3467.82) > 2658.6800537109375)
# decision node 15665 : (X_test[5, Debt Consolidation Loan] = 0.0) <= 1.5)
# decision node 15666 : (X_test[5, Num_Credit_Card] = 6.0) <= 9.5)
# decision node 15667 : (X_test[5, Interest_Rate] = 19.0) > 16.5)
# decision node 15855 : (X_test[5, Interest_Rate] = 19.0) > 18.5)
# decision node 16061 : (X_test[5, Delay_from_due_date] = 24.0) > 16.5)
# decision node 16147 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4830.619873046875)
# decision node 16148 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4628.10986328125)
# decision node 16149 : (X_test[5, Annual_Income] = 38721.44) <= 75964.80078125)
# decision node 16150 : (X_test[5, Outstanding_Debt] = 3467.82) > 2771.0550537109375)
# decision node 16242 : (X_test[5, Changed_Credit_Limit] = 20.87) <= 23.675000190734863)
# decision node 16243 : (X_test[5, Interest_Rate] = 19.0) <= 26.5)
# decision node 16244 : (X_test[5, Outstanding_Debt] = 3467.82) <= 4538.599853515625)
# decision node 16245 : (X_test[5, Annual_Income] = 38721.44) > 19660.669921875)
# decision node 16269 : (X_test[5, Changed_Credit_Limit] = 20.87) > 20.565000534057617)
# decision node 16285 : (X_test[5, Changed_Credit_Limit] = 20.87) <= 21.984999656677246)
# decision node 16286 : (X_test[5, Interest_Rate] = 19.0) <= 19.5)
# decision node 16287 : (X_test[5, Credit_History_Age] = 165.0) > 160.0)
# Sample 5 is Standard
# **************************************************
#
# Rules used to predict sample 6:
#
# decision node 0 : (X_test[6, Credit_Mix] = 2.0) > 1.5)
# decision node 18256 : (X_test[6, Num_Credit_Card] = 7.0) > 2.5)
# decision node 20170 : (X_test[6, Delay_from_due_date] = 11.0) <= 15.5)
# decision node 20171 : (X_test[6, Num_Credit_Card] = 7.0) > 5.5)
# decision node 25241 : (X_test[6, Num_Bank_Accounts] = 3.0) <= 5.5)
# decision node 25242 : (X_test[6, Changed_Credit_Limit] = 4.77) > 2.6350001096725464)
# decision node 25838 : (X_test[6, Num_of_Delayed_Payment] = 5.0) <= 13.5)
# decision node 25839 : (X_test[6, Num_Credit_Card] = 7.0) > 6.5)
# decision node 26715 : (X_test[6, Outstanding_Debt] = 534.4) <= 863.3949890136719)
# decision node 26716 : (X_test[6, Debt Consolidation Loan] = 0.0) <= 0.5)
# decision node 26717 : (X_test[6, Outstanding_Debt] = 534.4) > 16.80500030517578)
# decision node 26727 : (X_test[6, Changed_Credit_Limit] = 4.77) <= 10.654999732971191)
# decision node 26728 : (X_test[6, Outstanding_Debt] = 534.4) > 52.209999084472656)
# decision node 26754 : (X_test[6, Credit_History_Age] = 266.0) <= 392.5)
# decision node 26755 : (X_test[6, Annual_Income] = 40646.19) > 18856.1318359375)
# decision node 26787 : (X_test[6, Annual_Income] = 40646.19) <= 41750.259765625)
# decision node 26788 : (X_test[6, Changed_Credit_Limit] = 4.77) <= 4.9049999713897705)
# decision node 26789 : (X_test[6, Outstanding_Debt] = 534.4) <= 733.52001953125)
# decision node 26790 : (X_test[6, Annual_Income] = 40646.19) > 20875.4482421875)
# decision node 26804 : (X_test[6, Credit_History_Age] = 266.0) > 258.5)
# decision node 26816 : (X_test[6, Num_Credit_Inquiries] = 4.0) > 0.5)
# decision node 26820 : (X_test[6, Interest_Rate] = 6.0) <= 10.0)
# Sample 6 is Standard
# **************************************************
#
# Rules used to predict sample 7:
#
# decision node 0 : (X_test[7, Credit_Mix] = 2.0) > 1.5)
# decision node 18256 : (X_test[7, Num_Credit_Card] = 6.0) > 2.5)
# decision node 20170 : (X_test[7, Delay_from_due_date] = 26.0) > 15.5)
# decision node 27990 : (X_test[7, Num_of_Delayed_Payment] = 8.0) <= 12.5)
# decision node 27991 : (X_test[7, Num_Bank_Accounts] = 5.0) <= 5.5)
# decision node 27992 : (X_test[7, Delay_from_due_date] = 26.0) > 20.5)
# decision node 28810 : (X_test[7, Num_Bank_Accounts] = 5.0) > 2.5)
# decision node 29182 : (X_test[7, Num_of_Delayed_Payment] = 8.0) > 5.5)
# decision node 29298 : (X_test[7, Annual_Income] = 34447.49) <= 65692.62890625)
# decision node 29299 : (X_test[7, Annual_Income] = 34447.49) <= 35517.599609375)
# decision node 29300 : (X_test[7, Interest_Rate] = 4.0) <= 10.5)
# decision node 29301 : (X_test[7, Credit_History_Age] = 366.0) > 359.5)
# decision node 29359 : (X_test[7, Changed_Credit_Limit] = 8.71) > 3.950000047683716)
# decision node 29367 : (X_test[7, Interest_Rate] = 4.0) <= 6.5)
# decision node 29368 : (X_test[7, Credit_History_Age] = 366.0) <= 384.5)
# decision node 29369 : (X_test[7, Delay_from_due_date] = 26.0) <= 31.5)
# decision node 29370 : (X_test[7, Annual_Income] = 34447.49) > 17655.955078125)
# decision node 29372 : (X_test[7, Changed_Credit_Limit] = 8.71) <= 11.994999885559082)
# Sample 7 is Good
# **************************************************
#
# Rules used to predict sample 8:
#
# decision node 0 : (X_test[8, Credit_Mix] = 2.0) > 1.5)
# decision node 18256 : (X_test[8, Num_Credit_Card] = 1.0) <= 2.5)
# decision node 18257 : (X_test[8, Annual_Income] = 90674.43) <= 118044.65625)
# decision node 18258 : (X_test[8, Annual_Income] = 90674.43) > 33388.37890625)
# decision node 18860 : (X_test[8, Outstanding_Debt] = 29.87) <= 1142.6650390625)
# decision node 18861 : (X_test[8, Credit_History_Age] = 209.0) > 205.5)
# decision node 18973 : (X_test[8, Credit_History_Age] = 209.0) <= 245.5)
# decision node 18974 : (X_test[8, Annual_Income] = 90674.43) > 37693.515625)
# decision node 18976 : (X_test[8, Outstanding_Debt] = 29.87) <= 484.6649932861328)
# decision node 18977 : (X_test[8, Credit_History_Age] = 209.0) <= 211.5)
# Sample 8 is Good
# **************************************************
#
# Rules used to predict sample 9:
#
# decision node 0 : (X_test[9, Credit_Mix] = 1.0) <= 1.5)
# decision node 1 : (X_test[9, Outstanding_Debt] = 154.94) <= 1255.469970703125)
# decision node 2 : (X_test[9, Annual_Income] = 97515.78) > 93708.23828125)
# decision node 5154 : (X_test[9, Num_Credit_Inquiries] = 5.0) <= 8.5)
# decision node 5155 : (X_test[9, Annual_Income] = 97515.78) <= 125990.90234375)
# decision node 5156 : (X_test[9, Credit_History_Age] = 397.0) > 324.5)
# decision node 5950 : (X_test[9, Num_Credit_Inquiries] = 5.0) > 1.5)
# decision node 6036 : (X_test[9, Num_Bank_Accounts] = 5.0) > 4.5)
# decision node 6120 : (X_test[9, Annual_Income] = 97515.78) > 93947.2578125)
# decision node 6132 : (X_test[9, Credit_History_Age] = 397.0) > 329.5)
# decision node 6142 : (X_test[9, Annual_Income] = 97515.78) <= 105116.0390625)
# decision node 6143 : (X_test[9, Outstanding_Debt] = 154.94) <= 470.8450012207031)
# decision node 6144 : (X_test[9, Num_of_Loan] = 0.0) <= 1.5)
# decision node 6145 : (X_test[9, Delay_from_due_date] = 6.0) <= 20.5)
# decision node 6146 : (X_test[9, Num_of_Delayed_Payment] = 9.0) <= 10.0)
# decision node 6147 : (X_test[9, Credit_History_Age] = 397.0) > 349.5)
# decision node 6149 : (X_test[9, Credit_History_Age] = 397.0) > 394.5)
# Sample 9 is Standard
# **************************************************
